# %% [markdown]
# # [Quanvolutional Neural Networks](https://pennylane.ai/qml/demos/tutorial_quanvolution/)
#
# ## General setup

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# Out:
# 2024-08-10 06:39:55.751568: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-10 06:39:56.199371: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-10 06:39:56.199413: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-10 06:39:56.279620: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-10 06:39:56.418432: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-10 06:39:57.357080: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Setting of the main hyper-parameters of the model
# =================================================

# %%
n_epochs = 30   # Number of optimization epochs
n_layers = 1    # Number of random layers
n_train = 50    # Size of the train dataset
n_test = 30     # Size of the test dataset

SAVE_PATH = "."  # Data saving folder
PREPROCESS = True           # If False, skip quantum processing and load data from SAVE_PATH
np.random.seed(0)           # Seed for NumPy random number generator
tf.random.set_seed(0)       # Seed for TensorFlow random number generator

# %% [markdown]
# Loading of the MNIST dataset
# ============================

# %%
mnist_dataset = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist_dataset.load_data()

# Reduce dataset size
train_images = train_images[:n_train]
train_labels = train_labels[:n_train]
test_images = test_images[:n_test]
test_labels = test_labels[:n_test]

# Normalize pixel values within 0 and 1 (data preprocessing)
train_images = train_images / 255
test_images = test_images / 255

# Add extra dimension for convolution channels
train_images = np.array(train_images[..., tf.newaxis], requires_grad=False)
test_images = np.array(test_images[..., tf.newaxis], requires_grad=False)

# %% [markdown]
# Quantum circuit as a convolution kernel
# =======================================

# %%
dev = qml.device("default.qubit", wires=4)
# Random circuit parameters
rand_params = np.random.uniform(high=2 * np.pi, size=(n_layers, 4))

@qml.qnode(dev)
def circuit(phi):
    # Encoding of 4 classical input values
    for j in range(4):
        qml.RY(np.pi * phi[j], wires=j)

    # Random quantum circuit
    RandomLayers(rand_params, wires=list(range(4)))

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# %%
def quanv(image):
    """Convolves the input image with many applications of the same quantum circuit."""
    out = np.zeros((14, 14, 4))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 28, 2):
        for k in range(0, 28, 2):
            # Process a squared 2x2 region of the image with a quantum circuit
            q_results = circuit(
                [
                    image[j, k, 0],
                    image[j, k + 1, 0],
                    image[j + 1, k, 0],
                    image[j + 1, k + 1, 0]
                ]
            )
            # Assign expectation values to different channels of the output pixel (j/2, k/2)
            for c in range(4):
                out[j // 2, k // 2, c] = q_results[c]
    return out

# %% [markdown]
# Quantum pre-processing of the dataset
# =====================================

# %%
if PREPROCESS == True:
    q_train_images = []
    print("Quantum pre-processing of train images:")
    for idx, img in enumerate(train_images):
        print("{}/{}        ".format(idx + 1, n_train), end="\r")
        q_train_images.append(quanv(img))
    q_train_images = np.asarray(q_train_images)

    q_test_images = []
    print("\nQuantum pre-processing of test images:")
    for idx, img in enumerate(test_images):
        print("{}/{}        ".format(idx + 1, n_test), end="\r")
        q_test_images.append(quanv(img))
    q_test_images = np.asarray(q_test_images)

    # Save pre-processed images
    np.save(SAVE_PATH + "q_train_images.npy", q_train_images)
    np.save(SAVE_PATH + "q_test_images.npy", q_test_images)


# Load pre-processed images
q_train_images = np.load(SAVE_PATH + "q_train_images.npy")
q_test_images = np.load(SAVE_PATH + "q_test_images.npy")
# Out:
# Quantum pre-processing of train images:
# 50/50
# Quantum pre-processing of test images:
# 30/30

# %%
n_samples = 4
n_channels = 4
fig, axes = plt.subplots(1 + n_channels, n_samples, figsize=(10, 10))
for k in range(n_samples):
    axes[0, 0].set_ylabel("Input")
    if k != 0:
        axes[0, k].yaxis.set_visible(False)
    axes[0, k].imshow(train_images[k, :, :, 0], cmap="gray")

    # Plot all output channels
    for c in range(n_channels):
        axes[c + 1, 0].set_ylabel("Output [ch. {}]".format(c))
        if k != 0:
            axes[c, k].yaxis.set_visible(False)
        axes[c + 1, k].imshow(q_train_images[k, :, :, c], cmap="gray")

plt.tight_layout()
plt.show()

# %% [markdown]
# Hybrid quantum-classical model
# ==============================

# %%
def MyModel():
    """Initializes and returns a custom Keras model
    which is ready to be trained."""
    model = keras.models.Sequential([
        keras.layers.Flatten(),
        keras.layers.Dense(10, activation="softmax") # classify images to 0~9
    ])

    model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

# %% [markdown]
# Training
# ========

# %%
# Hybrid quantum-classical model
q_model = MyModel()

q_history = q_model.fit(
    q_train_images,
    train_labels,
    validation_data=(q_test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 13/13 - 0s - loss: 2.8698 - accuracy: 0.1000 - val_loss: 2.3135 - val_accuracy: 0.2000 - 377ms/epoch - 29ms/step
# Epoch 2/30
# 13/13 - 0s - loss: 2.1429 - accuracy: 0.1600 - val_loss: 2.2039 - val_accuracy: 0.2333 - 86ms/epoch - 7ms/step
# Epoch 3/30
# 13/13 - 0s - loss: 1.7762 - accuracy: 0.3800 - val_loss: 2.0726 - val_accuracy: 0.3667 - 82ms/epoch - 6ms/step
# Epoch 4/30
# 13/13 - 0s - loss: 1.4273 - accuracy: 0.6600 - val_loss: 1.8597 - val_accuracy: 0.4000 - 80ms/epoch - 6ms/step
# Epoch 5/30
# 13/13 - 0s - loss: 1.1885 - accuracy: 0.7400 - val_loss: 1.7214 - val_accuracy: 0.5000 - 75ms/epoch - 6ms/step
# Epoch 6/30
# 13/13 - 0s - loss: 1.0211 - accuracy: 0.8600 - val_loss: 1.6795 - val_accuracy: 0.5000 - 65ms/epoch - 5ms/step
# Epoch 7/30
# 13/13 - 0s - loss: 0.8180 - accuracy: 0.9000 - val_loss: 1.5858 - val_accuracy: 0.5000 - 65ms/epoch - 5ms/step
# Epoch 8/30
# 13/13 - 0s - loss: 0.6782 - accuracy: 0.9800 - val_loss: 1.4959 - val_accuracy: 0.5667 - 62ms/epoch - 5ms/step
# Epoch 9/30
# 13/13 - 0s - loss: 0.5888 - accuracy: 0.9600 - val_loss: 1.4374 - val_accuracy: 0.5667 - 64ms/epoch - 5ms/step
# Epoch 10/30
# 13/13 - 0s - loss: 0.4923 - accuracy: 1.0000 - val_loss: 1.4247 - val_accuracy: 0.5667 - 85ms/epoch - 7ms/step
# Epoch 11/30
# 13/13 - 0s - loss: 0.4545 - accuracy: 1.0000 - val_loss: 1.3773 - val_accuracy: 0.6000 - 71ms/epoch - 5ms/step
# Epoch 12/30
# 13/13 - 0s - loss: 0.4005 - accuracy: 1.0000 - val_loss: 1.4044 - val_accuracy: 0.5333 - 65ms/epoch - 5ms/step
# Epoch 13/30
# 13/13 - 0s - loss: 0.3585 - accuracy: 1.0000 - val_loss: 1.3093 - val_accuracy: 0.6333 - 67ms/epoch - 5ms/step
# Epoch 14/30
# 13/13 - 0s - loss: 0.3297 - accuracy: 0.9800 - val_loss: 1.2764 - val_accuracy: 0.7000 - 62ms/epoch - 5ms/step
# Epoch 15/30
# 13/13 - 0s - loss: 0.2739 - accuracy: 1.0000 - val_loss: 1.2659 - val_accuracy: 0.7000 - 70ms/epoch - 5ms/step
# Epoch 16/30
# 13/13 - 0s - loss: 0.2446 - accuracy: 1.0000 - val_loss: 1.2784 - val_accuracy: 0.6667 - 71ms/epoch - 5ms/step
# Epoch 17/30
# 13/13 - 0s - loss: 0.2279 - accuracy: 1.0000 - val_loss: 1.2333 - val_accuracy: 0.6000 - 68ms/epoch - 5ms/step
# Epoch 18/30
# 13/13 - 0s - loss: 0.2038 - accuracy: 1.0000 - val_loss: 1.2345 - val_accuracy: 0.6333 - 65ms/epoch - 5ms/step
# Epoch 19/30
# 13/13 - 0s - loss: 0.1851 - accuracy: 1.0000 - val_loss: 1.2277 - val_accuracy: 0.7000 - 64ms/epoch - 5ms/step
# Epoch 20/30
# 13/13 - 0s - loss: 0.1721 - accuracy: 1.0000 - val_loss: 1.1871 - val_accuracy: 0.7000 - 85ms/epoch - 7ms/step
# Epoch 21/30
# 13/13 - 0s - loss: 0.1566 - accuracy: 1.0000 - val_loss: 1.2133 - val_accuracy: 0.6667 - 70ms/epoch - 5ms/step
# Epoch 22/30
# 13/13 - 0s - loss: 0.1431 - accuracy: 1.0000 - val_loss: 1.1925 - val_accuracy: 0.6333 - 64ms/epoch - 5ms/step
# Epoch 23/30
# 13/13 - 0s - loss: 0.1348 - accuracy: 1.0000 - val_loss: 1.1652 - val_accuracy: 0.7000 - 63ms/epoch - 5ms/step
# Epoch 24/30
# 13/13 - 0s - loss: 0.1256 - accuracy: 1.0000 - val_loss: 1.1551 - val_accuracy: 0.7000 - 71ms/epoch - 5ms/step
# Epoch 25/30
# 13/13 - 0s - loss: 0.1202 - accuracy: 1.0000 - val_loss: 1.1550 - val_accuracy: 0.6667 - 73ms/epoch - 6ms/step
# Epoch 26/30
# 13/13 - 0s - loss: 0.1087 - accuracy: 1.0000 - val_loss: 1.1538 - val_accuracy: 0.7000 - 65ms/epoch - 5ms/step
# Epoch 27/30
# 13/13 - 0s - loss: 0.1036 - accuracy: 1.0000 - val_loss: 1.1450 - val_accuracy: 0.7000 - 67ms/epoch - 5ms/step
# Epoch 28/30
# 13/13 - 0s - loss: 0.1013 - accuracy: 1.0000 - val_loss: 1.1359 - val_accuracy: 0.6667 - 81ms/epoch - 6ms/step
# Epoch 29/30
# 13/13 - 0s - loss: 0.0932 - accuracy: 1.0000 - val_loss: 1.1554 - val_accuracy: 0.6667 - 75ms/epoch - 6ms/step
# Epoch 30/30
# 13/13 - 0s - loss: 0.0865 - accuracy: 1.0000 - val_loss: 1.1288 - val_accuracy: 0.6667 - 64ms/epoch - 5ms/step

# %%
# classical model
c_model = MyModel()

c_history = c_model.fit(
    train_images,
    train_labels,
    validation_data=(test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 13/13 - 0s - loss: 2.3879 - accuracy: 0.0800 - val_loss: 2.1666 - val_accuracy: 0.2000 - 372ms/epoch - 29ms/step
# Epoch 2/30
# 13/13 - 0s - loss: 2.0096 - accuracy: 0.3400 - val_loss: 2.0242 - val_accuracy: 0.4333 - 68ms/epoch - 5ms/step
# Epoch 3/30
# 13/13 - 0s - loss: 1.7120 - accuracy: 0.6600 - val_loss: 1.8893 - val_accuracy: 0.4667 - 62ms/epoch - 5ms/step
# Epoch 4/30
# 13/13 - 0s - loss: 1.4770 - accuracy: 0.8000 - val_loss: 1.7556 - val_accuracy: 0.4333 - 64ms/epoch - 5ms/step
# Epoch 5/30
# 13/13 - 0s - loss: 1.2666 - accuracy: 0.8400 - val_loss: 1.6309 - val_accuracy: 0.5333 - 71ms/epoch - 5ms/step
# Epoch 6/30
# 13/13 - 0s - loss: 1.0977 - accuracy: 0.9000 - val_loss: 1.5373 - val_accuracy: 0.6000 - 64ms/epoch - 5ms/step
# Epoch 7/30
# 13/13 - 0s - loss: 0.9539 - accuracy: 0.9200 - val_loss: 1.4685 - val_accuracy: 0.6333 - 65ms/epoch - 5ms/step
# Epoch 8/30
# 13/13 - 0s - loss: 0.8370 - accuracy: 0.9200 - val_loss: 1.4008 - val_accuracy: 0.7000 - 66ms/epoch - 5ms/step
# Epoch 9/30
# 13/13 - 0s - loss: 0.7397 - accuracy: 0.9200 - val_loss: 1.3453 - val_accuracy: 0.7000 - 65ms/epoch - 5ms/step
# Epoch 10/30
# 13/13 - 0s - loss: 0.6559 - accuracy: 0.9600 - val_loss: 1.3034 - val_accuracy: 0.7667 - 66ms/epoch - 5ms/step
# Epoch 11/30
# 13/13 - 0s - loss: 0.5921 - accuracy: 0.9600 - val_loss: 1.2591 - val_accuracy: 0.7667 - 66ms/epoch - 5ms/step
# Epoch 12/30
# 13/13 - 0s - loss: 0.5354 - accuracy: 0.9600 - val_loss: 1.2479 - val_accuracy: 0.7667 - 66ms/epoch - 5ms/step
# Epoch 13/30
# 13/13 - 0s - loss: 0.4828 - accuracy: 0.9800 - val_loss: 1.2167 - val_accuracy: 0.7667 - 61ms/epoch - 5ms/step
# Epoch 14/30
# 13/13 - 0s - loss: 0.4359 - accuracy: 1.0000 - val_loss: 1.1780 - val_accuracy: 0.7667 - 72ms/epoch - 6ms/step
# Epoch 15/30
# 13/13 - 0s - loss: 0.3965 - accuracy: 1.0000 - val_loss: 1.1529 - val_accuracy: 0.7667 - 65ms/epoch - 5ms/step
# Epoch 16/30
# 13/13 - 0s - loss: 0.3632 - accuracy: 1.0000 - val_loss: 1.1350 - val_accuracy: 0.7667 - 65ms/epoch - 5ms/step
# Epoch 17/30
# 13/13 - 0s - loss: 0.3352 - accuracy: 1.0000 - val_loss: 1.1190 - val_accuracy: 0.7667 - 68ms/epoch - 5ms/step
# Epoch 18/30
# 13/13 - 0s - loss: 0.3090 - accuracy: 1.0000 - val_loss: 1.0946 - val_accuracy: 0.7667 - 64ms/epoch - 5ms/step
# Epoch 19/30
# 13/13 - 0s - loss: 0.2843 - accuracy: 1.0000 - val_loss: 1.0877 - val_accuracy: 0.7667 - 65ms/epoch - 5ms/step
# Epoch 20/30
# 13/13 - 0s - loss: 0.2641 - accuracy: 1.0000 - val_loss: 1.0675 - val_accuracy: 0.7667 - 66ms/epoch - 5ms/step
# Epoch 21/30
# 13/13 - 0s - loss: 0.2454 - accuracy: 1.0000 - val_loss: 1.0638 - val_accuracy: 0.7667 - 63ms/epoch - 5ms/step
# Epoch 22/30
# 13/13 - 0s - loss: 0.2278 - accuracy: 1.0000 - val_loss: 1.0495 - val_accuracy: 0.7667 - 63ms/epoch - 5ms/step
# Epoch 23/30
# 13/13 - 0s - loss: 0.2125 - accuracy: 1.0000 - val_loss: 1.0387 - val_accuracy: 0.7667 - 65ms/epoch - 5ms/step
# Epoch 24/30
# 13/13 - 0s - loss: 0.1984 - accuracy: 1.0000 - val_loss: 1.0284 - val_accuracy: 0.7667 - 64ms/epoch - 5ms/step
# Epoch 25/30
# 13/13 - 0s - loss: 0.1878 - accuracy: 1.0000 - val_loss: 1.0225 - val_accuracy: 0.7667 - 65ms/epoch - 5ms/step
# Epoch 26/30
# 13/13 - 0s - loss: 0.1751 - accuracy: 1.0000 - val_loss: 1.0150 - val_accuracy: 0.7667 - 64ms/epoch - 5ms/step
# Epoch 27/30
# 13/13 - 0s - loss: 0.1655 - accuracy: 1.0000 - val_loss: 1.0038 - val_accuracy: 0.7667 - 65ms/epoch - 5ms/step
# Epoch 28/30
# 13/13 - 0s - loss: 0.1568 - accuracy: 1.0000 - val_loss: 0.9965 - val_accuracy: 0.7667 - 62ms/epoch - 5ms/step
# Epoch 29/30
# 13/13 - 0s - loss: 0.1475 - accuracy: 1.0000 - val_loss: 0.9952 - val_accuracy: 0.7333 - 75ms/epoch - 6ms/step
# Epoch 30/30
# 13/13 - 0s - loss: 0.1391 - accuracy: 1.0000 - val_loss: 0.9899 - val_accuracy: 0.7333 - 61ms/epoch - 5ms/step

# %% [markdown]
# Results
# =======

# %%
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8")
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 9))

ax1.plot(q_history.history["val_accuracy"], "-ob", label="With quantum layer")
ax1.plot(c_history.history["val_accuracy"], "-og", label="Without quantum layer")
ax1.set_ylabel("Accuracy")
ax1.set_ylim([0, 1])
ax1.set_xlabel("Epoch")
ax1.legend()

ax2.plot(q_history.history["val_loss"], "-ob", label="With quantum layer")
ax2.plot(c_history.history["val_loss"], "-og", label="Without quantum layer")
ax2.set_ylabel("Loss")
ax2.set_ylim(top=2.5)
ax2.set_xlabel("Epoch")
ax2.legend()
plt.tight_layout()
plt.show()
# adding quantum layer does not improve the accuracy...
